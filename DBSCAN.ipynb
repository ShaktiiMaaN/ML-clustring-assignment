# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
X, y = make_moons(n_samples=500, noise=0.1)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, label=y)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
# Out:
# Text(0, 0.5, '$x_2$')

# %%
#Using Default parameters
dbscan_cluster1 = DBSCAN()
dbscan_cluster1.fit(X)
plt.scatter(X[:, 0], 
            X[:, 1], 
            c=dbscan_cluster1.labels_, 
            label=y)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
# Out:
# Text(0, 0.5, '$x_2$')

# %%
#Changing the parameters
dbscan_cluster2 = DBSCAN(eps=0.2, min_samples=5)
dbscan_cluster2.fit(X)
plt.scatter(X[:, 0], 
            X[:, 1], 
            c=dbscan_cluster2.labels_, 
            label=y)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
# Out:
# Text(0, 0.5, '$x_2$')

# %%
#another parameter
dbscan_cluster3 = DBSCAN(eps=0.2, min_samples=15)
dbscan_cluster3.fit(X)
plt.scatter(X[:, 0], 
            X[:, 1], 
            c=dbscan_cluster3.labels_, 
            label=y)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
# Out:
# Text(0, 0.5, '$x_2$')

# %%
#another parameter
dbscan_cluster4 = DBSCAN(eps=0.2, min_samples=20)
dbscan_cluster4.fit(X)
plt.scatter(X[:, 0], 
            X[:, 1], 
            c=dbscan_cluster4.labels_, 
            label=y)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
# Out:
# Text(0, 0.5, '$x_2$')

# %%
#another parameter
dbscan_cluster4 = DBSCAN(eps=0.2, min_samples=25)
dbscan_cluster4.fit(X)
plt.scatter(X[:, 0], 
            X[:, 1], 
            c=dbscan_cluster4.labels_, 
            label=y)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
# Out:
# Text(0, 0.5, '$x_2$')

# %%
#another parameter
dbscan_cluster4 = DBSCAN(eps=0.2, min_samples=30)
dbscan_cluster4.fit(X)
plt.scatter(X[:, 0], 
            X[:, 1], 
            c=dbscan_cluster4.labels_, 
            label=y)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
# Out:
# Text(0, 0.5, '$x_2$')
